# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv('car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %% [markdown]
# Data analysis to-
# Check Missing values
# Check Dimensions
# Check data type
# Check the number of unique values of each column
# Check statistics of data set
# Check various categories present in the different categorical column

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.duplicated().sum()
# Out:
# 2

# %%
# Check for duplicates and create a new column "Is_Duplicate"
df['Is_Duplicate'] = df.duplicated()
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_10372\1938724917.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Is_Duplicate'] = df.duplicated()

# %%
df = df.drop_duplicates(subset=['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
       'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'])

# %%
# Drop the "Is_Duplicate" column if not needed
df.drop(columns=['Is_Duplicate'], inplace=True)

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [299 rows x 9 columns]

# %%
numerical_columns = ['Year', 'Selling_Price', 'Present_Price', 'Driven_kms', 'Owner']

# Create a DataFrame containing only the numerical columns
numerical_df = df[numerical_columns]

# %%
numerical_df
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms  Owner
# 0    2014           3.35           5.59       27000      0
# 1    2013           4.75           9.54       43000      0
# 2    2017           7.25           9.85        6900      0
# 3    2011           2.85           4.15        5200      0
# 4    2014           4.60           6.87       42450      0
# ..    ...            ...            ...         ...    ...
# 296  2016           9.50          11.60       33988      0
# 297  2015           4.00           5.90       60000      0
# 298  2009           3.35          11.00       87934      0
# 299  2017          11.50          12.50        9000      0
# 300  2016           5.30           5.90        5464      0
#
# [299 rows x 5 columns]

# %%
# checking the distribution of categorical data
print(df['Fuel_Type'].value_counts())
print(df['Selling_type'].value_counts())
print(df['Transmission'].value_counts())
# Out:
# Fuel_Type
# Petrol    239
# Diesel     58
# CNG         2
# Name: count, dtype: int64
# Selling_type
# Dealer        193
# Individual    106
# Name: count, dtype: int64
# Transmission
# Manual       260
# Automatic     39
# Name: count, dtype: int64

# %% [markdown]
# Categorical data visualization

# %%
# Define the list of categorical columns to analyze
categorical_columns = ['Fuel_Type', 'Selling_type','Transmission']

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 5))
axes = axes.ravel()  # Flatten the 2D array of axes

# Loop through each categorical column
for i, column in enumerate(categorical_columns):
    sns.countplot(x=df[column], data=df, palette='bright', ax=axes[i], saturation=0.95)
    for container in axes[i].containers:
        axes[i].bar_label(container, color='black', size=10)
    axes[i].set_title(f'Count Plot of {column.capitalize()}')
    axes[i].set_xlabel(column.capitalize())
    axes[i].set_ylabel('Count')

# Adjust layout and show plots
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_10372\3220474140.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], data=df, palette='bright', ax=axes[i], saturation=0.95)
# C:\Users\sumit\AppData\Local\Temp\ipykernel_10372\3220474140.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], data=df, palette='bright', ax=axes[i], saturation=0.95)
# C:\Users\sumit\AppData\Local\Temp\ipykernel_10372\3220474140.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df[column], data=df, palette='bright', ax=axes[i], saturation=0.95)

# %% [markdown]
# Encoding

# %%
# encoding "Fuel_Type" Column
df.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)

# encoding "Seller_Type" Column
df.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)

# encoding "Transmission" Column
df.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          0
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          0
# 3    wagon r  2011           2.85           4.15        5200          0
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          0
# 298     city  2009           3.35          11.00       87934          0
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          0
#
#      Selling_type  Transmission  Owner
# 0               0             0      0
# 1               0             0      0
# 2               0             0      0
# 3               0             0      0
# 4               0             0      0
# ..            ...           ...    ...
# 296             0             0      0
# 297             0             0      0
# 298             0             0      0
# 299             0             0      0
# 300             0             0      0
#
# [299 rows x 9 columns]

# %%
X = df.drop(['Car_Name','Selling_Price'],axis=1)
Y = df['Selling_Price']

# %%
X
# Out:
#      Year  Present_Price  Driven_kms  Fuel_Type  Selling_type  Transmission  \
# 0    2014           5.59       27000          0             0             0
# 1    2013           9.54       43000          1             0             0
# 2    2017           9.85        6900          0             0             0
# 3    2011           4.15        5200          0             0             0
# 4    2014           6.87       42450          1             0             0
# ..    ...            ...         ...        ...           ...           ...
# 296  2016          11.60       33988          1             0             0
# 297  2015           5.90       60000          0             0             0
# 298  2009          11.00       87934          0             0             0
# 299  2017          12.50        9000          1             0             0
# 300  2016           5.90        5464          0             0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 296      0
# 297      0
# 298      0
# 299      0
# 300      0
#
# [299 rows x 7 columns]

# %%
Y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %% [markdown]
# Split the dataset into training and testing sets

# %%
from sklearn.linear_model import LinearRegression
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=13)

# %% [markdown]
# Training Model and Prediction

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)

# %%
print(f'The Test_accuracy: {model.score(X_test,Y_test)*100:.2f}')
#Train score for the data
print(f'The Train_accuracy: {model.score(X_train,Y_train)*100:.2f}')
# Out:
# The Test_accuracy: 89.16
# The Train_accuracy: 87.12

# %% [markdown]
# Evaluate model using MSE and R2_score

# %%
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 2.41
# R-squared (R2): 0.89

# %%
plt.figure(figsize=(10, 6))
plt.scatter(Y_test, Y_pred, alpha=0.5)
plt.xlabel('Actual Selling Price')
plt.ylabel('Predicted Selling Price')
plt.title('Actual vs. Predicted Selling Prices (Linear Regression)')
plt.show()

# %%
pred_df=pd.DataFrame({'Actual Value':Y_test,'Predicted Value':Y_pred,'Difference':Y_test-Y_pred})
pred_df
# Out:
#      Actual Value  Predicted Value  Difference
# 265          6.50         6.472267    0.027733
# 120          1.05         1.716329   -0.666329
# 199          0.12        -2.428593    2.548593
# 81           4.75         6.540008   -1.790008
# 31           2.35         2.236168    0.113832
# 83          12.50         8.998997    3.501003
# 52          18.00        14.291193    3.708807
# 62          18.75        19.807381   -1.057381
# 59          19.99        20.015056   -0.025056
# 259          3.90         4.452902   -0.552902
# 228          4.95         5.909804   -0.959804
# 172          0.40         0.604743   -0.204743
# 160          0.45        -0.512055    0.962055
# 12           7.50         7.865692   -0.365692
# 13           6.10         5.217204    0.882796
# 213          2.90         3.192007   -0.292007
# 251          5.00         5.204264   -0.204264
# 297          4.00         4.236626   -0.236626
# 177          0.35         2.926302   -2.576302
# 194          0.20        -1.923354    2.123354
# 80          14.73        10.105210    4.624790
# 286          5.65         5.683767   -0.033767
# 174          0.38         0.897971   -0.517971
# 9            7.45         6.993587    0.456413
# 270          4.10         4.380786   -0.280786
# 130          0.75         1.914497   -1.164497
# 281          2.10         1.449205    0.650795
# 35           2.95         6.183868   -3.233868
# 216          2.90         4.259925   -1.359925
# 99           9.65         9.990985   -0.340985
# 47           1.05        -0.137737    1.187737
# 185          0.25        -0.129945    0.379945
# 250         12.90         9.469759    3.430241
# 287          5.75         6.638295   -0.888295
# 152          0.50        -0.034779    0.534779
# 7            6.50         6.908495   -0.408495
# 211         11.75         9.548237    2.201763
# 209          4.85         5.707860   -0.857860
# 205          5.25         4.093777    1.156223
# 290          4.50         4.286831    0.213169
# 244          5.95         6.369627   -0.419627
# 285          7.40         7.635140   -0.235140
# 114          1.15         1.346449   -0.196449
# 271          3.00         3.583382   -0.583382
# 221          4.50         5.599698   -1.099698
# 55           3.60         7.393733   -3.793733
# 241          4.75         4.137930    0.612070
# 150          0.50        -0.465127    0.965127
# 207          5.15         5.904572   -0.754572
# 237         11.25         8.891696    2.358304
# 72           7.45         9.008552   -1.558552
# 256         10.25         8.052968    2.197032
# 137          0.65         0.257891    0.392109
# 255          3.00         2.837905    0.162095
# 248          4.00         3.041629    0.958371
# 42           1.95         2.006680   -0.056680
# 154          0.50         0.741454   -0.241454
# 68           4.35         5.907898   -1.557898
# 116          1.10         0.460480    0.639520
# 24           2.90         2.807861    0.092139
